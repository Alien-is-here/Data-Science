# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = {'Name':['a','b','c','d','a','b'],
        "Eng":[10,20,20,30,10,40],
        "Maths":[30,30,40,45,30,5]
        }

# %%
df = pd.DataFrame(data)
df
# Out:
#   Name  Eng  Maths
# 0    a   10     30
# 1    b   20     30
# 2    c   20     40
# 3    d   30     45
# 4    a   10     30
# 5    b   40      5

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
#df["dupliacted"] = df.duplicated()
#df

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#   Name  Eng  Maths
# 0    a   10     30
# 1    b   20     30
# 2    c   20     40
# 3    d   30     45
# 5    b   40      5

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tanishaj225/loancsv")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/tanishaj225/loancsv?dataset_version_number=1...
# 100%|██████████| 7.79k/7.79k [00:00<00:00, 4.59MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/tanishaj225/loancsv/versions/1

# %%
import os

path = "/root/.cache/kagglehub/datasets/tanishaj225/loancsv/versions/1"
files = os.listdir(path)
print(files)
# Out:
# ['loan.csv']

# %%
file_name = "loan.csv"
file_path = os.path.join(path, file_name)

import pandas as pd
data = pd.read_csv(file_path)
print(data.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
d = pd.DataFrame(data)
d.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
d.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
d.duplicated().sum()
# Out:
# 0
